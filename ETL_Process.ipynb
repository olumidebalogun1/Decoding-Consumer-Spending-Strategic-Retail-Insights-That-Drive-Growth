# %% [markdown]
# #  ETL (Extract, Transform, Load) Process

# %% [markdown]
# ## This section outlines the ETL process used to prepare the data for analysis. It involves:

# %% [markdown]
# ###  1. Extracting raw datasets from various sources (Sales_January, Sales_February, ... , and Sales_December),

# %% [markdown]
# ###  2.  Transforming the data by:
# -  merging sources,
# -  correcting data types,
# -  handling missing values,
# -  removing duplicates to ensure consistency and accuracy,
# -  changing the data type to optimize memory usage,
# -  expanding the dataset with supplementary columns,
# -  organizing oata by Order date chronologically and reindexing,
# -  and formating float datatype to ensure consistency and accuracy,

# %% [markdown]
# ### 3.     And finally, Loading the cleaned and structured data into the analysis environment for further exploration and modelling.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %% [markdown]
# ## Combining sales data from all months into a single consolidated CSV file.

# %%
# Defining the folder path
folder_path = r"C:\Monthly_Sales"

file_names = [
    "Sales_January_2024.csv", "Sales_February_2024.csv", "Sales_March_2024.csv", "Sales_April_2024.csv",
    "Sales_May_2024.csv", "Sales_June_2024.csv", "Sales_July_2024.csv", "Sales_August_2024.csv",
    "Sales_September_2024.csv", "Sales_October_2024.csv", "Sales_November_2024.csv", "Sales_December_2024.csv"
]

# Creating full paths to each file
full_paths = [f"{folder_path}\\{file}" for file in file_names]

# Reading and combining all files into one DataFrame
joined_data = pd.concat([pd.read_csv(file) for file in full_paths], ignore_index=True)

# Saving the joined DataFrame into a new CSV file named "joined_data.csv"
output_file = f"{folder_path}\\joined_data.csv"
joined_data.to_csv(output_file, index=False)

print("All files integrated into:", output_file)
# Out:
# All files integrated into: C:\Monthly_Sales\joined_data.csv

# %% [markdown]
# ## Loading the updated DataFrame

# %%
# Skip Blank Rows if present in the dataset

df = pd.read_csv(r'C:\Monthly_Sales\joined_data.csv', skip_blank_lines=True)
df.head()
# Out:
#   Order ID             Product Name Units Purchased Unit Price  \
# 0   141234  Dell UltraSharp Monitor               1     410.99
# 1   141235   AAA Batteries (4-pack)               1       4.99
# 2   141236    AA Batteries (4-pack)               1       5.84
# 3   141237     USB-C Charging Cable               1      11.95
# 4   141238  Samsung Odyssey Monitor               1     409.99
#
#        Order Date                            Delivery Address
# 0  01/10/24 10:27  590 Washington St, New York City, NY 10001
# 1  01/22/24 09:33         208 1st St, San Francisco, CA 94016
# 2  01/19/24 19:11         53 Meadow St, Los Angeles, CA 90001
# 3  01/30/24 13:34            800 Dogwood St, Austin, TX 73301
# 4  01/16/24 08:56         746 4th St, San Francisco, CA 94016

# %%
df.shape
# Out:
# (172531, 6)

# %% [markdown]
# ## Data Cleaning Process
#
# Thoroughly clean and standardize the data to eliminate errors, ensure consistency, and build a solid foundation for meaningful insights.

# %% [markdown]
# ### Find and remove rows with NaN values

# %%
df.isna().sum()
# Out:
# Order ID            448
# Product Name        448
# Units Purchased     448
# Unit Price          448
# Order Date          448
# Delivery Address    448
# dtype: int64

# %%
# If Nan value is present in Order ID and Unit Purchased, it will be impossible to manipulate the data.
# Therefore, drop Nan values in Order ID and Units Purchased.

df.dropna(subset=['Order ID', 'Units Purchased'], inplace=True)

# %%
# Check if Nan value is present

df.isna().sum()
# Out:
# Order ID            0
# Product Name        0
# Units Purchased     0
# Unit Price          0
# Order Date          0
# Delivery Address    0
# dtype: int64

# %%
# Further check if any NaN values or blank rows are present

blank_rows_na = df[df.isnull().any(axis=1)]
blank_rows_na
# Out:
# Empty DataFrame
# Columns: [Order ID, Product Name, Units Purchased, Unit Price, Order Date, Delivery Address]
# Index: []

# %% [markdown]
# ### Find and remove rows with duplicate values

# %%
# Find duplicate values

df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 172526    False
# 172527    False
# 172528    False
# 172529    False
# 172530    False
# Length: 172083, dtype: bool

# %% [markdown]
# ### Verifying and correcting incorrect data types in the dataset.

# %%
# check for data types

df.dtypes
# Out:
# Order ID            object
# Product Name        object
# Units Purchased     object
# Unit Price          object
# Order Date          object
# Delivery Address    object
# dtype: object

# %% [markdown]
# ###  Correcting incorrect data types

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%y %H:%M', errors='coerce')

df['Units Purchased'] = pd. to_numeric(df['Units Purchased'], errors='coerce')

df['Unit Price'] = pd. to_numeric(df['Unit Price'], errors='coerce')

# %%
# Verify the presence of NaN values remaining in the columns as a result of using errors='coerce' during data conversion.

df.isna().sum()
# Out:
# Order ID              0
# Product Name          0
# Units Purchased     303
# Unit Price          303
# Order Date          303
# Delivery Address      0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ### Changing the data type to optimize memory usage (Optional)

# %%
df['Order ID'] = pd.to_numeric(df['Order ID'], downcast='integer') 
df['Product Name'] = df['Product Name'].astype('category')  
df['Units Purchased'] = df['Units Purchased']. astype('int8') 
df['Unit Price'] = pd.to_numeric(df['Unit Price'], downcast='float')   
df['Delivery Address'] = df['Delivery Address'].astype('category')

# %% [markdown]
# ## Expanding the dataset with supplementary columns

# %% [markdown]
# ### Adding month column

# %%
df['Month'] = df['Order Date'].dt.month
df
# Out:
#         Order ID                Product Name  Units Purchased  Unit Price  \
# 0         141234     Dell UltraSharp Monitor                1  410.989990
# 1         141235      AAA Batteries (4-pack)                1    4.990000
# 2         141236       AA Batteries (4-pack)                1    5.840000
# 3         141237        USB-C Charging Cable                1   11.950000
# 4         141238     Samsung Odyssey Monitor                1  409.989990
# ...          ...                         ...              ...         ...
# 172526    306090  Bose SoundSport Headphones                1   99.989998
# 172527    306091    Lightning Charging Cable                1   14.950000
# 172528    306092      Galaxy buds Headphones                1  120.000000
# 172529    306093  Bose SoundSport Headphones                1   99.989998
# 172530    306094        USB-C Charging Cable                1   11.950000
#
#                 Order Date                            Delivery Address  Month
# 0      2024-01-10 10:27:00  590 Washington St, New York City, NY 10001      1
# 1      2024-01-22 09:33:00         208 1st St, San Francisco, CA 94016      1
# 2      2024-01-19 19:11:00         53 Meadow St, Los Angeles, CA 90001      1
# 3      2024-01-30 13:34:00            800 Dogwood St, Austin, TX 73301      1
# 4      2024-01-16 08:56:00         746 4th St, San Francisco, CA 94016      1
# ...                    ...                                         ...    ...
# 172526 2024-12-11 12:34:00     148 Johnson St, San Francisco, CA 94016     12
# 172527 2024-12-26 22:39:00         892 7th St, New York City, NY 10001     12
# 172528 2024-12-18 12:16:00       565 Ridge St, San Francisco, CA 94016     12
# 172529 2024-12-10 06:24:00       94 Forest St, New York City, NY 10001     12
# 172530 2024-12-16 18:41:00             137 Main St, Portland, OR 97035     12
#
# [171780 rows x 7 columns]

# %%
df['Month Name'] = df['Order Date'].dt.strftime('%B')
df
# Out:
#         Order ID                Product Name  Units Purchased  Unit Price  \
# 0         141234     Dell UltraSharp Monitor                1  410.989990
# 1         141235      AAA Batteries (4-pack)                1    4.990000
# 2         141236       AA Batteries (4-pack)                1    5.840000
# 3         141237        USB-C Charging Cable                1   11.950000
# 4         141238     Samsung Odyssey Monitor                1  409.989990
# ...          ...                         ...              ...         ...
# 172526    306090  Bose SoundSport Headphones                1   99.989998
# 172527    306091    Lightning Charging Cable                1   14.950000
# 172528    306092      Galaxy buds Headphones                1  120.000000
# 172529    306093  Bose SoundSport Headphones                1   99.989998
# 172530    306094        USB-C Charging Cable                1   11.950000
#
#                 Order Date                            Delivery Address  Month  \
# 0      2024-01-10 10:27:00  590 Washington St, New York City, NY 10001      1
# 1      2024-01-22 09:33:00         208 1st St, San Francisco, CA 94016      1
# 2      2024-01-19 19:11:00         53 Meadow St, Los Angeles, CA 90001      1
# 3      2024-01-30 13:34:00            800 Dogwood St, Austin, TX 73301      1
# 4      2024-01-16 08:56:00         746 4th St, San Francisco, CA 94016      1
# ...                    ...                                         ...    ...
# 172526 2024-12-11 12:34:00     148 Johnson St, San Francisco, CA 94016     12
# 172527 2024-12-26 22:39:00         892 7th St, New York City, NY 10001     12
# 172528 2024-12-18 12:16:00       565 Ridge St, San Francisco, CA 94016     12
# 172529 2024-12-10 06:24:00       94 Forest St, New York City, NY 10001     12
# 172530 2024-12-16 18:41:00             137 Main St, Portland, OR 97035     12
#
#        Month Name
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
# ...           ...
# 172526   December
# 172527   December
# 172528   December
# 172529   December
# 172530   December
#
# [171780 rows x 8 columns]

# %% [markdown]
# ### Adding Year Column

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Now safely extract the year
df['Year'] = df['Order Date'].dt.year

# %% [markdown]
# ### Adding week day column

# %%
df['Day of Week'] = df['Order Date'].dt.strftime('%a')
df
# Out:
#         Order ID                Product Name  Units Purchased  Unit Price  \
# 0         141234     Dell UltraSharp Monitor                1  410.989990
# 1         141235      AAA Batteries (4-pack)                1    4.990000
# 2         141236       AA Batteries (4-pack)                1    5.840000
# 3         141237        USB-C Charging Cable                1   11.950000
# 4         141238     Samsung Odyssey Monitor                1  409.989990
# ...          ...                         ...              ...         ...
# 172526    306090  Bose SoundSport Headphones                1   99.989998
# 172527    306091    Lightning Charging Cable                1   14.950000
# 172528    306092      Galaxy buds Headphones                1  120.000000
# 172529    306093  Bose SoundSport Headphones                1   99.989998
# 172530    306094        USB-C Charging Cable                1   11.950000
#
#                 Order Date                            Delivery Address  Month  \
# 0      2024-01-10 10:27:00  590 Washington St, New York City, NY 10001      1
# 1      2024-01-22 09:33:00         208 1st St, San Francisco, CA 94016      1
# 2      2024-01-19 19:11:00         53 Meadow St, Los Angeles, CA 90001      1
# 3      2024-01-30 13:34:00            800 Dogwood St, Austin, TX 73301      1
# 4      2024-01-16 08:56:00         746 4th St, San Francisco, CA 94016      1
# ...                    ...                                         ...    ...
# 172526 2024-12-11 12:34:00     148 Johnson St, San Francisco, CA 94016     12
# 172527 2024-12-26 22:39:00         892 7th St, New York City, NY 10001     12
# 172528 2024-12-18 12:16:00       565 Ridge St, San Francisco, CA 94016     12
# 172529 2024-12-10 06:24:00       94 Forest St, New York City, NY 10001     12
# 172530 2024-12-16 18:41:00             137 Main St, Portland, OR 97035     12
#
#        Month Name  Year Day of Week
# 0         January  2024         Wed
# 1         January  2024         Mon
# 2         January  2024         Fri
# 3         January  2024         Tue
# 4         January  2024         Tue
# ...           ...   ...         ...
# 172526   December  2024         Wed
# 172527   December  2024         Thu
# 172528   December  2024         Wed
# 172529   December  2024         Tue
# 172530   December  2024         Mon
#
# [171780 rows x 10 columns]

# %% [markdown]
# ### Adding hour column

# %%
df['Hour'] = df['Order Date'].dt.hour
df
# Out:
#         Order ID                Product Name  Units Purchased  Unit Price  \
# 0         141234     Dell UltraSharp Monitor                1  410.989990
# 1         141235      AAA Batteries (4-pack)                1    4.990000
# 2         141236       AA Batteries (4-pack)                1    5.840000
# 3         141237        USB-C Charging Cable                1   11.950000
# 4         141238     Samsung Odyssey Monitor                1  409.989990
# ...          ...                         ...              ...         ...
# 172526    306090  Bose SoundSport Headphones                1   99.989998
# 172527    306091    Lightning Charging Cable                1   14.950000
# 172528    306092      Galaxy buds Headphones                1  120.000000
# 172529    306093  Bose SoundSport Headphones                1   99.989998
# 172530    306094        USB-C Charging Cable                1   11.950000
#
#                 Order Date                            Delivery Address  Month  \
# 0      2024-01-10 10:27:00  590 Washington St, New York City, NY 10001      1
# 1      2024-01-22 09:33:00         208 1st St, San Francisco, CA 94016      1
# 2      2024-01-19 19:11:00         53 Meadow St, Los Angeles, CA 90001      1
# 3      2024-01-30 13:34:00            800 Dogwood St, Austin, TX 73301      1
# 4      2024-01-16 08:56:00         746 4th St, San Francisco, CA 94016      1
# ...                    ...                                         ...    ...
# 172526 2024-12-11 12:34:00     148 Johnson St, San Francisco, CA 94016     12
# 172527 2024-12-26 22:39:00         892 7th St, New York City, NY 10001     12
# 172528 2024-12-18 12:16:00       565 Ridge St, San Francisco, CA 94016     12
# 172529 2024-12-10 06:24:00       94 Forest St, New York City, NY 10001     12
# 172530 2024-12-16 18:41:00             137 Main St, Portland, OR 97035     12
#
#        Month Name  Year Day of Week  Hour
# 0         January  2024         Wed    10
# 1         January  2024         Mon     9
# 2         January  2024         Fri    19
# 3         January  2024         Tue    13
# 4         January  2024         Tue     8
# ...           ...   ...         ...   ...
# 172526   December  2024         Wed    12
# 172527   December  2024         Thu    22
# 172528   December  2024         Wed    12
# 172529   December  2024         Tue     6
# 172530   December  2024         Mon    18
#
# [171780 rows x 11 columns]

# %% [markdown]
# ### Adding city column

# %%
def city(address):
    return address.split(",")[1].strip(" ")

def state_abbrev(address):
    return address.split(",")[2].split(" ")[1]

df['City'] = df['Delivery Address'].apply(lambda x: f"{city(x)}  ({state_abbrev(x)})")
df.head()
# Out:
#    Order ID             Product Name  Units Purchased  Unit Price  \
# 0    141234  Dell UltraSharp Monitor                1   410.98999
# 1    141235   AAA Batteries (4-pack)                1     4.99000
# 2    141236    AA Batteries (4-pack)                1     5.84000
# 3    141237     USB-C Charging Cable                1    11.95000
# 4    141238  Samsung Odyssey Monitor                1   409.98999
#
#            Order Date                            Delivery Address  Month  \
# 0 2024-01-10 10:27:00  590 Washington St, New York City, NY 10001      1
# 1 2024-01-22 09:33:00         208 1st St, San Francisco, CA 94016      1
# 2 2024-01-19 19:11:00         53 Meadow St, Los Angeles, CA 90001      1
# 3 2024-01-30 13:34:00            800 Dogwood St, Austin, TX 73301      1
# 4 2024-01-16 08:56:00         746 4th St, San Francisco, CA 94016      1
#
#   Month Name  Year Day of Week  Hour                 City
# 0    January  2024         Wed    10  New York City  (NY)
# 1    January  2024         Mon     9  San Francisco  (CA)
# 2    January  2024         Fri    19    Los Angeles  (CA)
# 3    January  2024         Tue    13         Austin  (TX)
# 4    January  2024         Tue     8  San Francisco  (CA)

# %% [markdown]
# ## Organizing Data by Order Date Chronologically and Reindex

# %%
df = df.sort_values(by = 'Order Date')
df
# Out:
#         Order ID                Product Name  Units Purchased  Unit Price  \
# 19768     160155           Alienware Monitor                1  400.989990
# 10247     151041      AAA Batteries (4-pack)                1    4.990000
# 5789      146765      AAA Batteries (4-pack)                1    4.990000
# 4578      145617       Amana Washing Machine                1  600.000000
# 15989     156535    Lightning Charging Cable                2   14.950000
# ...          ...                         ...              ...         ...
# 163805    297748        USB-C Charging Cable                2   11.950000
# 150010    284606  Bose SoundSport Headphones                1   99.989998
# 168593    302330       AA Batteries (4-pack)                1    5.840000
# 150117    284711       AA Batteries (4-pack)                1    5.840000
# 169966    303626        USB-C Charging Cable                3   11.950000
#
#                 Order Date                      Delivery Address  Month  \
# 19768  2024-01-01 05:04:00      765 Ridge St, Portland, OR 97035      1
# 10247  2024-01-01 05:04:00    964 Lakeview St, Atlanta, GA 30301      1
# 5789   2024-01-01 05:20:00  546 10th St, San Francisco, CA 94016      1
# 4578   2024-01-01 05:24:00     961 Meadow St, Portland, OR 97035      1
# 15989  2024-01-01 05:45:00     451 Elm St, Los Angeles, CA 90001      1
# ...                    ...                                   ...    ...
# 163805 2025-01-01 02:37:00  258 Forest St, Los Angeles, CA 90001      1
# 150010 2025-01-01 02:50:00      211 Johnson St, Boston, MA 02215      1
# 168593 2025-01-01 03:03:00   665 6th St, San Francisco, CA 94016      1
# 150117 2025-01-01 03:19:00   250 8th St, San Francisco, CA 94016      1
# 169966 2025-01-01 04:43:00     651 Lakeview St, Dallas, TX 75001      1
#
#        Month Name  Year Day of Week  Hour                 City
# 19768     January  2024         Mon     5       Portland  (OR)
# 10247     January  2024         Mon     5        Atlanta  (GA)
# 5789      January  2024         Mon     5  San Francisco  (CA)
# 4578      January  2024         Mon     5       Portland  (OR)
# 15989     January  2024         Mon     5    Los Angeles  (CA)
# ...           ...   ...         ...   ...                  ...
# 163805    January  2025         Wed     2    Los Angeles  (CA)
# 150010    January  2025         Wed     2         Boston  (MA)
# 168593    January  2025         Wed     3  San Francisco  (CA)
# 150117    January  2025         Wed     3  San Francisco  (CA)
# 169966    January  2025         Wed     4         Dallas  (TX)
#
# [171780 rows x 12 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#         Order ID                Product Name  Units Purchased  Unit Price  \
# 0         160155           Alienware Monitor                1  400.989990
# 1         151041      AAA Batteries (4-pack)                1    4.990000
# 2         146765      AAA Batteries (4-pack)                1    4.990000
# 3         145617       Amana Washing Machine                1  600.000000
# 4         156535    Lightning Charging Cable                2   14.950000
# ...          ...                         ...              ...         ...
# 171775    297748        USB-C Charging Cable                2   11.950000
# 171776    284606  Bose SoundSport Headphones                1   99.989998
# 171777    302330       AA Batteries (4-pack)                1    5.840000
# 171778    284711       AA Batteries (4-pack)                1    5.840000
# 171779    303626        USB-C Charging Cable                3   11.950000
#
#                 Order Date                      Delivery Address  Month  \
# 0      2024-01-01 05:04:00      765 Ridge St, Portland, OR 97035      1
# 1      2024-01-01 05:04:00    964 Lakeview St, Atlanta, GA 30301      1
# 2      2024-01-01 05:20:00  546 10th St, San Francisco, CA 94016      1
# 3      2024-01-01 05:24:00     961 Meadow St, Portland, OR 97035      1
# 4      2024-01-01 05:45:00     451 Elm St, Los Angeles, CA 90001      1
# ...                    ...                                   ...    ...
# 171775 2025-01-01 02:37:00  258 Forest St, Los Angeles, CA 90001      1
# 171776 2025-01-01 02:50:00      211 Johnson St, Boston, MA 02215      1
# 171777 2025-01-01 03:03:00   665 6th St, San Francisco, CA 94016      1
# 171778 2025-01-01 03:19:00   250 8th St, San Francisco, CA 94016      1
# 171779 2025-01-01 04:43:00     651 Lakeview St, Dallas, TX 75001      1
#
#        Month Name  Year Day of Week  Hour                 City
# 0         January  2024         Mon     5       Portland  (OR)
# 1         January  2024         Mon     5        Atlanta  (GA)
# 2         January  2024         Mon     5  San Francisco  (CA)
# 3         January  2024         Mon     5       Portland  (OR)
# 4         January  2024         Mon     5    Los Angeles  (CA)
# ...           ...   ...         ...   ...                  ...
# 171775    January  2025         Wed     2    Los Angeles  (CA)
# 171776    January  2025         Wed     2         Boston  (MA)
# 171777    January  2025         Wed     3  San Francisco  (CA)
# 171778    January  2025         Wed     3  San Francisco  (CA)
# 171779    January  2025         Wed     4         Dallas  (TX)
#
# [171780 rows x 12 columns]

# %% [markdown]
# ## Adding Total Sales column

# %%
df['Total Sales'] = df['Units Purchased'] * df['Unit Price']
df.head()
# Out:
#    Order ID              Product Name  Units Purchased  Unit Price  \
# 0    160155         Alienware Monitor                1   400.98999
# 1    151041    AAA Batteries (4-pack)                1     4.99000
# 2    146765    AAA Batteries (4-pack)                1     4.99000
# 3    145617     Amana Washing Machine                1   600.00000
# 4    156535  Lightning Charging Cable                2    14.95000
#
#            Order Date                      Delivery Address  Month Month Name  \
# 0 2024-01-01 05:04:00      765 Ridge St, Portland, OR 97035      1    January
# 1 2024-01-01 05:04:00    964 Lakeview St, Atlanta, GA 30301      1    January
# 2 2024-01-01 05:20:00  546 10th St, San Francisco, CA 94016      1    January
# 3 2024-01-01 05:24:00     961 Meadow St, Portland, OR 97035      1    January
# 4 2024-01-01 05:45:00     451 Elm St, Los Angeles, CA 90001      1    January
#
#    Year Day of Week  Hour                 City  Total Sales
# 0  2024         Mon     5       Portland  (OR)    400.98999
# 1  2024         Mon     5        Atlanta  (GA)      4.99000
# 2  2024         Mon     5  San Francisco  (CA)      4.99000
# 3  2024         Mon     5       Portland  (OR)    600.00000
# 4  2024         Mon     5    Los Angeles  (CA)     29.90000

# %% [markdown]
# ## Formatting Unit Price and Total Sales to two decimal places.

# %%
df['Unit Price'] = df['Unit Price'].apply(lambda x: "%.2f" % x)

# %%
df['Total Sales'] = df['Total Sales'].apply(lambda x: "%.2f" % x)
df.head()
# Out:
#    Order ID              Product Name  Units Purchased Unit Price  \
# 0    160155         Alienware Monitor                1     400.99
# 1    151041    AAA Batteries (4-pack)                1       4.99
# 2    146765    AAA Batteries (4-pack)                1       4.99
# 3    145617     Amana Washing Machine                1     600.00
# 4    156535  Lightning Charging Cable                2      14.95
#
#            Order Date                      Delivery Address  Month Month Name  \
# 0 2024-01-01 05:04:00      765 Ridge St, Portland, OR 97035      1    January
# 1 2024-01-01 05:04:00    964 Lakeview St, Atlanta, GA 30301      1    January
# 2 2024-01-01 05:20:00  546 10th St, San Francisco, CA 94016      1    January
# 3 2024-01-01 05:24:00     961 Meadow St, Portland, OR 97035      1    January
# 4 2024-01-01 05:45:00     451 Elm St, Los Angeles, CA 90001      1    January
#
#    Year Day of Week  Hour                 City Total Sales
# 0  2024         Mon     5       Portland  (OR)      400.99
# 1  2024         Mon     5        Atlanta  (GA)        4.99
# 2  2024         Mon     5  San Francisco  (CA)        4.99
# 3  2024         Mon     5       Portland  (OR)      600.00
# 4  2024         Mon     5    Los Angeles  (CA)       29.90

# %% [markdown]
# ### Converting to numeric

# %%
df['Unit Price'] = pd.to_numeric(df['Unit Price'])
df['Total Sales'] = pd.to_numeric(df['Total Sales'])

# %%
df.dtypes
# Out:
# Order ID                     int32
# Product Name              category
# Units Purchased               int8
# Unit Price                 float64
# Order Date          datetime64[ns]
# Delivery Address          category
# Month                        int32
# Month Name                  object
# Year                         int32
# Day of Week                 object
# Hour                         int32
# City                        object
# Total Sales                float64
# dtype: object

# %%
df.head()
# Out:
#    Order ID              Product Name  Units Purchased  Unit Price  \
# 0    160155         Alienware Monitor                1      400.99
# 1    151041    AAA Batteries (4-pack)                1        4.99
# 2    146765    AAA Batteries (4-pack)                1        4.99
# 3    145617     Amana Washing Machine                1      600.00
# 4    156535  Lightning Charging Cable                2       14.95
#
#            Order Date                      Delivery Address  Month Month Name  \
# 0 2024-01-01 05:04:00      765 Ridge St, Portland, OR 97035      1    January
# 1 2024-01-01 05:04:00    964 Lakeview St, Atlanta, GA 30301      1    January
# 2 2024-01-01 05:20:00  546 10th St, San Francisco, CA 94016      1    January
# 3 2024-01-01 05:24:00     961 Meadow St, Portland, OR 97035      1    January
# 4 2024-01-01 05:45:00     451 Elm St, Los Angeles, CA 90001      1    January
#
#    Year Day of Week  Hour                 City  Total Sales
# 0  2024         Mon     5       Portland  (OR)       400.99
# 1  2024         Mon     5        Atlanta  (GA)         4.99
# 2  2024         Mon     5  San Francisco  (CA)         4.99
# 3  2024         Mon     5       Portland  (OR)       600.00
# 4  2024         Mon     5    Los Angeles  (CA)        29.90

# %%
df.describe()
# Out:
#             Order ID  Units Purchased     Unit Price  \
# count  171780.000000    171780.000000  171780.000000
# mean   223706.282122         1.072674     228.039622
# min    141234.000000         1.000000       4.990000
# 25%    182483.750000         1.000000      11.950000
# 50%    223736.500000         1.000000      99.990000
# 75%    264937.250000         1.000000     399.990000
# max    306094.000000         7.000000    1700.000000
# std     47585.469217         0.308029     367.043540
#
#                           Order Date          Month           Year  \
# count                         171780  171780.000000  171780.000000
# mean   2024-07-22 15:29:26.871463424       7.183147    2024.000210
# min              2024-01-01 05:04:00       1.000000    2024.000000
# 25%              2024-04-19 09:03:45       4.000000    2024.000000
# 50%              2024-07-27 19:17:30       7.000000    2024.000000
# 75%              2024-11-12 14:04:45      11.000000    2024.000000
# max              2025-01-01 04:43:00      12.000000    2025.000000
# std                              NaN       3.735458       0.014475
#
#                 Hour    Total Sales
# count  171780.000000  171780.000000
# mean       14.420468     229.105609
# min         0.000000       4.990000
# 25%        11.000000      11.950000
# 50%        15.000000      99.990000
# 75%        19.000000     399.990000
# max        23.000000    3400.000000
# std         5.427190     367.277013

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171780 entries, 0 to 171779
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          171780 non-null  int32
#  1   Product Name      171780 non-null  category
#  2   Units Purchased   171780 non-null  int8
#  3   Unit Price        171780 non-null  float64
#  4   Order Date        171780 non-null  datetime64[ns]
#  5   Delivery Address  171780 non-null  category
#  6   Month             171780 non-null  int32
#  7   Month Name        171780 non-null  object
#  8   Year              171780 non-null  int32
#  9   Day of Week       171780 non-null  object
#  10  Hour              171780 non-null  int32
#  11  City              171780 non-null  object
#  12  Total Sales       171780 non-null  float64
# dtypes: category(2), datetime64[ns](1), float64(2), int32(4), int8(1), object(3)
# memory usage: 16.5+ MB

# %% [markdown]
# ## Exporting Cleaned Data to CSV

# %%
df.to_csv("C:\\Monthly_Sales\\cleaned_data.csv", index=False)
